# %%
# %sql
CREATE CATALOG IF NOT EXISTS airquality
  MANAGED LOCATION 'abfss://silver@stairqualitydev01.dfs.core.windows.net/uc_catalog';

CREATE SCHEMA IF NOT EXISTS airquality.silver
  MANAGED LOCATION 'abfss://silver@stairqualitydev01.dfs.core.windows.net/uc_silver';

CREATE SCHEMA IF NOT EXISTS airquality.gold
  MANAGED LOCATION 'abfss://gold@stairqualitydev01.dfs.core.windows.net/uc_gold';
